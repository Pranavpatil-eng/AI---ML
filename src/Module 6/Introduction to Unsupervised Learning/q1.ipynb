# %%
# Title: Unsupervised Learning

# Task 1: Identifying patterns in customer purchasing behavior without any predefined categories.
# Task 2: Grouping news articles by topic without knowing what the topics are.
# Task 3:  Analyzing satellite images to identify different land use types without labeled data.



# Title: Difference Between Supervised & Unsupervised Learning

# Task 1:  Supervised Learning - Predicting house prices based on historical labeled data (e.g., size, location).
# Task 2:  Unsupervised Learning - Exploring the hidden demographics within a dataset of customerprofiles.
# Task 3:  Supervised Learning - Classifying emails as spam or not spam using labeled examples.
# Task 4:  Unsupervised Learning -  Grouping images of handwritten digits without knowing the digit labels.



# Title: Real-World Applications of Unsupervised Learning

# Customer Segmentation
# Task 1: Segmenting retail customers based on purchasing patterns.
# Task 2: Dividing social media users into groups based on engagement metrics.
# Task 3: Grouping telecom users by usage patterns to offer personalized plans.

# Anomoly Detection
# Task 1: Detecting fraudulent credit card transactions by identifying deviations from normal spending patterns.
# Task 2: Identifying unusual network activity indicating potential cybersecurity threats.
# Task 3: Monitoring industrial equipment for signs of failure by detecting abnormal operating conditions.

# Feature Reduction
# Task 1:  Using Principal Component Analysis (PCA) to reduce the dimensionality of image datasets for faster processing.
# Task 2: Applying feature reduction to sensor data in IoT devices to improve computational efficiency.
# Task 3:  Simplifying marketing datasets by merging related variables to uncover essential factors driving customer behavior.




# Title:  Types of Unsupervised Learning

# Clustering
# Task 1; Using K-means clustering to group customers into segments with similar purchasing behaviors.
# Task 2:  Applying hierarchical clustering to organize species based on genetic similarities.
# Task 3: Clustering web pages based on content similarity for improved search engine performance.
    
# Dimensionality Reduction
# Task 1: Applying PCA to reduce features in a facial recognition dataset.
# Task 2: Using t-SNE for visualizing high-dimensional data in a 2D plot.
# Task 3:  Employing Linear Discriminant Analysis to reduce variables in stock market prediction datasets.

# Association Rule Learning
# Task 1: Identifying products frequently bought together in market basket analysis.
# Task 2: Uncovering relationships between medical symptoms and diseases in healthcare data.
# Task 3: Finding associations between ingredients in cooking recipes.


# Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs
import random


# ---------------------- Unsupervised Learning Tasks ---------------------- #

# Task 1: Identifying patterns in customer purchasing behavior (Clustering)
# Using K-means clustering on a customer dataset (simulated here)
customer_data = pd.DataFrame({
    'Annual Income': np.random.uniform(30, 150, 200),  # Simulated data
    'Spending Score': np.random.uniform(1, 100, 200)
})
scaler = StandardScaler()
X = scaler.fit_transform(customer_data)

# K-Means Clustering
kmeans = KMeans(n_clusters=4, random_state=42)
customer_data['Cluster'] = kmeans.fit_predict(X)

# Visualize clusters
sns.scatterplot(x=customer_data['Annual Income'], y=customer_data['Spending Score'], hue=customer_data['Cluster'], palette='tab10')
plt.title("Customer Segmentation based on K-Means")
plt.show()

# Task 2: Grouping news articles by topic (Clustering)
# Simulated dataset of word counts in articles (use actual data in a real scenario)
news_data = np.random.rand(100, 10)  # Simulating 100 articles with 10 words' frequencies
kmeans = KMeans(n_clusters=5, random_state=42)
news_clusters = kmeans.fit_predict(news_data)

# Visualizing clustering results
plt.scatter(range(100), np.zeros(100), c=news_clusters, cmap='viridis')
plt.title("News Article Clusters")
plt.show()

# Task 3: Analyzing satellite images to identify land use types (Clustering)
# Simulated satellite data (Replace with actual image data)
satellite_data = np.random.rand(100, 5)  # 100 pixels with 5 features (e.g., color bands)
kmeans = KMeans(n_clusters=3, random_state=42)
satellite_clusters = kmeans.fit_predict(satellite_data)

# Visualize clustering
plt.scatter(range(100), np.zeros(100), c=satellite_clusters, cmap='coolwarm')
plt.title("Satellite Image Land Use Classification")
plt.show()


# ---------------------- Supervised vs Unsupervised Learning ---------------------- #

# Supervised Learning Example - Task 1: Predicting house prices (Regression)
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Simulated house price data (features: size and location)
house_data = pd.DataFrame({
    'Size': np.random.uniform(500, 5000, 100),
    'Location': np.random.uniform(0, 10, 100),
    'Price': np.random.uniform(100000, 1000000, 100)
})

X_house = house_data[['Size', 'Location']]
y_house = house_data['Price']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_house, y_house, test_size=0.2, random_state=42)

# Linear Regression Model
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# Task 2: Exploring hidden demographics (Unsupervised Learning)
from sklearn.decomposition import PCA

# Simulated customer demographic data
customer_demo = pd.DataFrame({
    'Age': np.random.randint(18, 80, 100),
    'Income': np.random.randint(20000, 100000, 100),
    'Spending Score': np.random.randint(1, 100, 100)
})

# PCA for dimensionality reduction
pca = PCA(n_components=2)
pca_result = pca.fit_transform(customer_demo)
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1])
plt.title("Customer Demographics - PCA")
plt.show()


# ---------------------- Real-World Applications of Unsupervised Learning ---------------------- #

# Customer Segmentation - Task 1: Segmenting retail customers based on purchasing patterns
# Using K-means clustering
purchases_data = pd.DataFrame({
    'Product_A': np.random.randint(0, 50, 100),
    'Product_B': np.random.randint(0, 50, 100),
    'Product_C': np.random.randint(0, 50, 100)
})

kmeans = KMeans(n_clusters=3, random_state=42)
purchases_data['Customer_Segment'] = kmeans.fit_predict(purchases_data)

# Task 2: Dividing social media users into groups based on engagement metrics
engagement_data = np.random.rand(100, 5)  # Simulated social media engagement data
kmeans = KMeans(n_clusters=4, random_state=42)
engagement_clusters = kmeans.fit_predict(engagement_data)

# Task 3: Grouping telecom users by usage patterns
usage_data = np.random.rand(100, 3)  # Telecom usage data (e.g., data usage, call duration)
kmeans = KMeans(n_clusters=2, random_state=42)
usage_clusters = kmeans.fit_predict(usage_data)


# ---------------------- Anomaly Detection ---------------------- #

# Task 1: Detecting fraudulent credit card transactions
transaction_data = np.random.rand(100, 5)  # Simulated transaction data
kmeans = KMeans(n_clusters=2, random_state=42)
transactions = kmeans.fit_predict(transaction_data)

# Task 2: Identifying unusual network activity (Anomaly Detection)
network_data = np.random.rand(100, 10)  # Simulated network data
kmeans = KMeans(n_clusters=2, random_state=42)
network_anomalies = kmeans.fit_predict(network_data)

# Task 3: Monitoring industrial equipment for signs of failure
equipment_data = np.random.rand(100, 4)  # Simulated sensor data
kmeans = KMeans(n_clusters=2, random_state=42)
equipment_status = kmeans.fit_predict(equipment_data)


# ---------------------- Feature Reduction ---------------------- #

# Task 1: Using PCA to reduce dimensionality of image datasets
image_data = np.random.rand(100, 50)  # Simulated image data
pca = PCA(n_components=2)
reduced_image_data = pca.fit_transform(image_data)

# Task 2: Applying feature reduction to IoT sensor data
sensor_data = np.random.rand(100, 10)  # IoT sensor data
pca = PCA(n_components=3)
reduced_sensor_data = pca.fit_transform(sensor_data)

# Task 3: Simplifying marketing datasets
marketing_data = pd.DataFrame({
    'Age': np.random.randint(18, 60, 100),
    'Income': np.random.randint(20000, 100000, 100),
    'Purchases': np.random.randint(0, 100, 100)
})

# PCA for feature reduction
pca = PCA(n_components=2)
reduced_marketing_data = pca.fit_transform(marketing_data)

# ---------------------- Types of Unsupervised Learning ---------------------- #

# Clustering Task 1: K-means clustering to group customers based on behavior
customer_behavior = np.random.rand(200, 5)  # Customer behavior data
kmeans = KMeans(n_clusters=4, random_state=42)
customer_behavior_clusters = kmeans.fit_predict(customer_behavior)

# Task 2: Hierarchical clustering for species
species_data = np.random.rand(30, 3)  # Simulated species data
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(species_data, 'ward')
dendrogram(Z)
plt.title("Hierarchical Clustering of Species")
plt.show()

# Task 3: Clustering web pages for search engines
webpage_data = np.random.rand(100, 20)  # Simulated webpage data
kmeans = KMeans(n_clusters=3, random_state=42)
webpage_clusters = kmeans.fit_predict(webpage_data)

# Dimensionality Reduction - Task 1: PCA for facial recognition data
facial_data = np.random.rand(100, 50)  # Simulated facial recognition data
pca = PCA(n_components=2)
reduced_facial_data = pca.fit_transform(facial_data)

# Task 2: Using t-SNE for high-dimensional data visualization
high_dim_data = np.random.rand(100, 30)  # High-dimensional data
tsne = TSNE(n_components=2, random_state=42)
reduced_data_tsne = tsne.fit_transform(high_dim_data)

# Task 3: Linear Discriminant Analysis for stock market prediction data
stock_data = np.random.rand(100, 5)  # Stock market features
lda = PCA(n_components=2)  # LDA implementation with PCA for simplicity here
reduced_stock_data = lda.fit_transform(stock_data)

# Association Rule Learning - Task 1: Market basket analysis
# Simulated transaction data
basket_data = [
    ['Milk', 'Eggs'],
    ['Eggs', 'Bread'],
    ['Milk', 'Bread', 'Eggs'],
    ['Bread', 'Butter']
]
from mlxtend.frequent_patterns import apriori, association_rules
basket_data_encoded = pd.get_dummies(pd.DataFrame(basket_data, columns=['Product1', 'Product2', 'Product3']))
frequent_itemsets = apriori(basket_data_encoded, min_support=0.1, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
print(rules)

# Task 2: Discovering relationships between medical symptoms and diseases (association rules)
# Replace with actual healthcare data for real tasks

# Task 3: Finding relationships between ingredients in cooking recipes
# Replace with actual recipes dataset for real tasks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 265
#     257 # Association Rule Learning - Task 1: Market basket analysis
#     258 # Simulated transaction data
#     259 basket_data = [
#     260     ['Milk', 'Eggs'],
#     261     ['Eggs', 'Bread'],
#     262     ['Milk', 'Bread', 'Eggs'],
#     263     ['Bread', 'Butter']
#     264 ]
# --> 265 from mlxtend.frequent_patterns import apriori, association_rules
#     266 basket_data_encoded = pd.get_dummies(pd.DataFrame(basket_data, columns=['Product1', 'Product2', 'Product3']))
#     267 frequent_itemsets = apriori(basket_data_encoded, min_support=0.1, use_colnames=True)
#
# ModuleNotFoundError: No module named 'mlxtend'
